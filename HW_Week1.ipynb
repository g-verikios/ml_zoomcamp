# %%
# Imports

import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.21.5'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Out:
# --2022-09-22 20:27:05--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: ‘data.csv.1’
#
# data.csv.1          100%[===================>]   1.41M  2.27MB/s    in 0.6s
#
# 2022-09-22 20:27:06 (2.27 MB/s) - ‘data.csv.1’ saved [1475504/1475504]

# %%
df = pd.read_csv('data.csv') # or just drop the link

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape[0] # number of records, datapoints
# Out:
# 11914

# %%
df.Make.value_counts().head(3) # find 3 most freq. car Makes
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %%
df[df['Make'] == 'Audi'].Model.nunique() # unique Audi car models
# Out:
# 34

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
(df.isnull().sum() != 0).sum() # or in one line
# Out:
# 5

# %%
median_engine_cyl = df['Engine Cylinders'].median()
median_engine_cyl
# Out:
# 6.0

# %%
df['Engine Cylinders'].value_counts().head(1)
# Out:
# 4.0    4752
# Name: Engine Cylinders, dtype: int64

# %%
mode_engine_cyl = df['Engine Cylinders'].mode()[0]
mode_engine_cyl
# Out:
# 4.0

# %%
df['Engine Cylinders'].fillna(mode_engine_cyl).median()
# Out:
# 6.0

# %% [markdown]
# median unchanged

# %%
lotus = df[df['Make'] ==  'Lotus']

# %%
lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
lotus = lotus[['Engine HP', 'Engine Cylinders']]
lotus = lotus.drop_duplicates()
lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
X = lotus.values
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = X.T.dot(X) # or X.T @ X, @ operator does the matrix multiplication
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])

# %%
w = (np.linalg.inv(XTX).dot(X.T)).dot(y)

# %%
w[0]
# Out:
# 4.594944810094551
